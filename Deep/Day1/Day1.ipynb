# %% [markdown]
# # Day 1 variables and Data types and operators

# %% [markdown]
# # 1: what is variable
# *variable is a name that store data in memory*
#
# # 2: Why use
# *Beacuse variable if dont use variable then we write hardcascode*
# *this is not good practice*
# *it is used in complex program and even all in all it is used in all code*
# *thats make consistency*
#
# # 3: Example:
#
# *Whit variable*
# `Name = "Akash"`
# `print(name)`
#
#
# *Whitout variable*
# `print("akash")`
# `print(2+3)`
# `print(3*4)`
#
#
# # 4: How to crate variables
#
# *Syntax*
# `variable_name` = value
#
# *Example*:
# `x = 10`
# `name = "akash"`
# `passed = true`
#
#
# # 5: Python dynamically typed
#
# *In python we do not need to declare data type name*
# *python autommatically dicide data type of a variable*
#
# `Ex:` int a = 10 `worng` || a= 10 is `right`
#
# *python always store latest valu in a variable*

# %%
# 1: variable 
name = "akash"
age = 17
print(f"Wellcome {name}\n your age is {age}")

# intgers variables
a = 18
b = 90
marks = 80

# float
percentage = 10.003
price = 99.99
pi = 3.14

# boolean
is_adult = True
is_student = False
i_passed = True or False


# string vriables
name = "akash"
greeting = "Hello, World!"
message = "Welcome to Python programing."
print(name)

# %%
name = "akash"
print(name)

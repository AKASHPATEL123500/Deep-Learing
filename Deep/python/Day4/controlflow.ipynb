# %% [markdown]
# # Control flow loops

# %% [markdown]
# # 1 : If statement

# %%
a = 10
b = 20

if a == b:
    print("a and b is equal")

x = 2
y = 2

if x == y:
    print(True)


age = 19

if age >= 18:
    print("u can vote")
# Out:
# True
# u can vote

# %% [markdown]
# # 1 : If else statement

# %%
marks = 100
akash = 100

if marks >= akash :
    print("pass")
else:
    print("fail")



database = {
    "name":"akash",
    "username":"akash_reddy_01",
    "email":"allahabadkin@gmail.com",
    "password":"akash1234",
    "role":"startup"
}

name = input("Enter your name: ")
username = input("Enter your username: ")
email = input("Enter your email: ")
password = input("Enter your password: ")
role = input("Enter your role: ")

if name != database["name"]:
    print("Name not match in database")
# Out:
# pass

# %%
data = "rahul"
name = input("Enter your name: ")
if(name != data):
    print("name is not match in db")
# Out:
# name is not match in db

# %% [markdown]
# # if else if statement

# %%
name = "akash"
city = "prayagraj"
age = 12

if(name != "akash"):
    print("name not match")
elif(city != "prayagraj"):
    print("invaild city")
elif(age != 12 ):
    print("age not match")
else:
    print(name,city,age)
# Out:
# akash prayagraj 12

# %%
marks = 85

if marks >= 100:
    print("Grade A+")
elif(marks >=90):
    print("Grade A")
elif(marks >= 80):
    print("Garde B+")
elif(marks >=70):
    print("Grade B")
elif(marks >= 60):
    print("Garde C+")
elif(marks >=50):
    print("Grade C")
else:
    print("fail")
# Out:
# Garde B+

# %% [markdown]
# # Nested if statement

# %%
age = 18
citizan = True

if age >= 18:
    if citizan :
        print("you can vote")
    else:
        print("your are not citizan")
else:
    print("Under age")
# Out:
# you can vote

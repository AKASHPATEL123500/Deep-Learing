# %%
name = "akash"
print(name)
# Out:
# akash

# %%
a = 10
b = 20
print(a+b)
c= a+b
print(c)
# Out:
# 30
# 30

# %%
name = input("Enter yout name: ")
print("thanks for entring your name " + name)
print("Welcome to the world of deep lerining " + name)
# Out:
# thanks for entring your name Kaahs
# Welcome to the world of deep lerining Kaahs

# %%
firstName = "Akash"
lastName = "Reddy"
fullName = firstName + lastName
print(fullName)
# Out:
# AkashReddy

# %%
firstName = "Akash"
lastName = "Reddy"
fullName = firstName + " "+ lastName
print(fullName)
# Out:
# Akash Reddy

# %%
name = "akash" + " reddy "
print(name)
# Out:
# akash reddy

# %%
numbers = [1,2,3,4,5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
student = "akash"
age = 17
marks = 95.5
is_passed = True
studentLst = [
    "akash",
    "rahul",
    "rhoit"
]
if(marks >= 90 ):
    print (is_passed)
# Out:
# True

# %%
number = "10" * 5
name = "loard shiva"
print(name)
print(name *5)
print(number)
# Out:
# loard shiva
# loard shivaloard shivaloard shivaloard shivaloard shiva
# 1010101010

# %%
a = 10
print(a)
a = 20
a = 100
print(a)
# Out:
# 10
# 100

# %%
x = 10
NAME = "AKASH"
FLOAT = 2.45
is_passed = True
print(type(x))

print(type(NAME))
print(type(FLOAT))
print(type(is_passed))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
a = 10
a = "akash"
a = True


x = y = z = 10
print(x)
print(a)
# Out:
# 10
# True

# %% [markdown]
# `input always return a string`
# `if we want to enter a number than we use int(input)`

# %%
name = input("Enter your name: ")
age = int(input("Enter a your age : "))

print(f"you are {age} year old ")

print("And your name is ", name)
# Out:
# you are 16 year old
# And your name is  Akash

# %% [markdown]
# # Indexing value in variabel string

# %%
text = "python"
print(text[0])
print(text[1])

# %%
a =13
print(a)

# %% [markdown]
# # Reverse

# %%
num = [1,2,3,4,5,6,7,8,9]
num.reverse()
print(num)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
num=[1,2,3,4]
b = num.copy()
print(b)
# Out:
# [1, 2, 3, 4]

# %%
num = [1,2,3,4,5,6,7,8,8,9,0,-0,0]
length = len(num)
print(length)
# Out:
# 13

# %% [markdown]
# # List slicing

# %%
lst = [1,2,3,4,5,23,4,5,6,7,8,9]
print(lst[1:2])
print(lst[0:3])
print(lst[:5])
print(lst[7:])
# Out:
# [2]
# [1, 2, 3]
# [1, 2, 3, 4, 5]
# [5, 6, 7, 8, 9]

# %% [markdown]
# # Membership check

# %%
lst = [1,2,3,4,5,6]
print(2 in lst)
print(5 in lst)
print(10 in lst)
# Out:
# True
# True
# False

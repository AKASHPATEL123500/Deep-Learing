# %% [markdown]
# ### Array creation
#
# 1. `0D array`
# 2. `1D array`
# 3. `2d array`
# 4. `3D array`
#
#
# ### NumPy array Types
#
# 1. `zeros((row,col))`
# 2. `ones((row,col))`
# 3. `full((row,col),value)`
# 4. `arnage(start,stop,step)`
# 5. `linspace(start, stop , num)`
# 6. `eye(3)`
# 7. `random.random((row , col))`
# 8. `random.rand((row , col))`
# 9. `random.radint(start,stop(row , col))`
#
#
# ### NumPy array data type
#
# 1. `print(array.dtype)`
#
#
# ## NumPy array size shape ndmin
#
# 1. `print(array.size)`
# 2. `print(array.ndmin)`
# 3. `print(array.shape)`

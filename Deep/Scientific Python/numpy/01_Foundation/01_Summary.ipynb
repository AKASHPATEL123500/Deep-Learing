# %% [markdown]
# # Summary of NumPy Foundation

# %% [markdown]
# ### 1. Array Creation using Numpy `(ndArray)`
#
# *1.* `firts array create using numpy (np.array(1))`
#
# *2.* `1D array create using numpy  np.array([1,2,3,4,5,5])`
#
# *3.* `2D  array create using numpy np.array([[1,2,3,4],[1,2,3,4]])`
#
# *4.* `3D  array create using numpy np.array([[1,2,3],[2,3,1],[1,2,3]])`

# %% [markdown]
# ### 2. NumPy array `size`, `ndim`, `shape`
#
# *2.1.* `Shape:` `array ki  row and col batata hai kitne row ka hai and col ka hai`
#
# *2.2.* `size:` `array ki size bata hai array me kitne elemnet hai ye bata hai`
#
# *2.3* `ndmin:` `array ki demenisal bata hai kitne ka matrixs hai ye jise 1D,2D,3D, etc `
#
# `Example : `
#
# *array = np.array([[1,2,3],[3,4,2]])*
#
# `print(array.size)` ----> `OutPut`: *total 6 elemnt*
#
# `print(array.ndmin)`----> `OutPut`: *2*  `yaha array 2D hai issliye 2`
#
# `print(array.shape)`----> `OutPut`: *(2,3)*  `tow row and three col hai iss array or matrixs mein!`

# %% [markdown]
# ### 3. Data Type in Numpy `(dtype)`
#
# *3.1.* `dtype:` `fundamentially hum dtype ka use array ki data type check karne ke liye karte hai`
#
# *Exmaple :*
#
# `print(array.dtype)` : *aise likhne se ye hume bata dega ki array ki kya size hai*

# %% [markdown]
# ### 4. NumPy array type
#
# *4.1.* `zeros((row,col)):` *all element are zero in zeros we define row and col in tuple form in zeros((3,3))*
#
# *4.2.* `ones((row,col)):` *all element are one in ones we define row and col in tuple form in zeros((3,3))*
#
# *4.3.* `full((row,col),value):`
#
#  *full me hum tuple me row and col define karte hai and kya number chaiye araay matrixs me wo define karte hai full((3,3),7)*
#
#
# *4.4.* `eye(3):`
#
# *eye() matrixs method me diagonal per 1 ho jata hai baki jab zero and yaha ek hi argumnet leta hai aur uske base per matrixs bana deta hai jise 3 denge to 3*3 ka  matrxi banayegea*
#
#
# *4.5.* `arnage(start,stop,step):`
#
#  *yaha value gen karta hai inn teno argument ke base per*
#
#
# *4.6.* `linspace(start,stop,num,endpoint=bol,retstep=bol):`
#
# *yaha ek num genarte karta hai*
#
# `start: `: *kaha se start karna hai hai*,
#
# `stop : `, *kaha tak jana hai*
#
# `num` : *kitne num prtint karne hai*
#
#
# `endpoint=True/False` : *last value include hogi ki nahi*
#
# `retstep=True/False` : *step size bhi retun kare tya nahi*
#
#
#
# *4.6.* `random.random((row,col)):` *gen random value and take two args in tuple row and col*
#
# *4.7.* `random.rand((row,col)):` *gen random value and take two args in tuple row and col*
#
# *4.6.* `random.(start,stop(row,col)):` *gen random value and take two args in tuple row and col*
#
# `Example : `
#
# *randient_martixs = np.random.randint(0,10,(3,3))   print(randient_martixs)*

# %% [markdown]
# ## Problem 9
#
# *ek random 3 and 3 ka array banao and jisme number `Normal Distrubution`  `(randn)`se aye hue ho*

# %%
import numpy as np

array = np.random.randn(3,3)
print(array)
# Out:
# [[-0.18584595  1.22619115  1.61623033]
#  [ 1.15578042 -0.18812231  1.0152414 ]
#  [-0.00761601  0.66387012 -0.10548469]]

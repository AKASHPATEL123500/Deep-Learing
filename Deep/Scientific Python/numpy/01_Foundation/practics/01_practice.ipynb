# %% [markdown]
# # Problem 01
#
# *Ek 5  and 5 ka array banao jisme keval 7 fill ho*

# %%
import numpy as np
array = np.full((5,5),7)
print(array)
# Out:
# [[7 7 7 7 7]
#  [7 7 7 7 7]
#  [7 7 7 7 7]
#  [7 7 7 7 7]
#  [7 7 7 7 7]]

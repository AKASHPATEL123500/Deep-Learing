# %% [markdown]
# ## Problem 3
#
# *array banao [1.2,2,1,2,3,1.2] aur usse int32 me convert karo and dekho kya hota hai*

# %%
import numpy as np

array = np.array([1.5,2.6,3.7], dtype='int32')
print(array)
# Out:
# [1 2 3]

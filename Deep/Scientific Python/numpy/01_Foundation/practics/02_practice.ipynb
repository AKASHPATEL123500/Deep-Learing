# %% [markdown]
# ## Problem 2
#
# _linspace ka use karo and 0 se 5 ke bech 10 barbar number genrate karo_

# %%
import numpy as np
array = np.linspace(0,5,10)
print(array)
# Out:
# [0 0 1 1 2 2 3 3 4 5]
